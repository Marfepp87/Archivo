# %% [markdown]
# <a href="https://colab.research.google.com/github/Marfepp87/Archivo/blob/main/PRAII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Estadistica descriptiva para identificar el tipo enfermendad eritematoescamosa

# %% [markdown]
# ##Importar Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Importa el dataset

# %%
link='https://raw.githubusercontent.com/Marfepp87/Archivo/main/dermatologia.data'
datos=pd.read_csv(link)
datos
# Out:
#      eritema  escala  ...  Edad  Código de clase
# 0          2       2  ...    55                2
# 1          3       3  ...     8                1
# 2          2       1  ...    26                3
# 3          2       2  ...    40                1
# 4          2       3  ...    45                3
# ..       ...     ...  ...   ...              ...
# 361        2       1  ...    25                4
# 362        3       2  ...    36                4
# 363        3       2  ...    28                3
# 364        2       1  ...    50                3
# 365        3       2  ...    35                1
#
# [366 rows x 35 columns]

# %%
##Tipologia de los Datos 
datos.dtypes
# Out:
# eritema                                         int64
# escala                                          int64
# fronteras_definidas                             int64
# picazón                                         int64
# fenómeno_de_koebner                             int64
# pápulas_poligonales                             int64
# pápulas_foliculares                             int64
# afectación_de_la_mucosa_oral                    int64
# afectación_de_la_rodilla_y_el_codo              int64
# afectación_del_cuero_cabelludo                  int64
# historia familiar                               int64
# incontinencia de melanina                       int64
# eosinófilos en el infiltrado                    int64
# infiltrado de PNL                               int64
# fibrosis de la dermis papilar                   int64
# exocitosis                                      int64
# acantosis                                       int64
# ...

# %%
#Validar Datos nulos
datos.isnull().sum()
# Out:
# eritema                                        0
# escala                                         0
# fronteras_definidas                            0
# picazón                                        0
# fenómeno_de_koebner                            0
# pápulas_poligonales                            0
# pápulas_foliculares                            0
# afectación_de_la_mucosa_oral                   0
# afectación_de_la_rodilla_y_el_codo             0
# afectación_del_cuero_cabelludo                 0
# historia familiar                              0
# incontinencia de melanina                      0
# eosinófilos en el infiltrado                   0
# infiltrado de PNL                              0
# fibrosis de la dermis papilar                  0
# exocitosis                                     0
# acantosis                                      0
# hiperqueratosis                                0
# paraqueratosis                                 0
# ...

# %%
##Crear subconjuntos
x=datos
